# %%
## Fagunjade Folajimi Daniel

# %matplotlib inline
import matplotlib.pyplot as plt

V_d = [i for i in range(-309,0)]
f = [((1.68 * (10**36)) * (0.6 - i))**(1/4) for i in V_d]

plt.figure(figsize = (15,7))
plt.plot(V_d, f)
plt.title("Plot of frequency against Applied Voltage", fontsize = 12)
plt.xlabel("Applied Voltage", fontsize = 13)
plt.ylabel("frequency", fontsize = 13)
# Out:
# Text(0, 0.5, 'frequency')
